# %% [markdown]
# # Cách chèn hình ảnh và bảng
# ![Sample](images/sample_plot.png)
#
# _Hình 1. Hình mẫu minh hoạ._

# %%
from IPython.display import Image, display
display(Image(filename="images/sample_plot.png"))
