# %% [markdown]
# # Báo cáo tối thiểu
# **Tác giả:** Phạm Ngọc Hưng – MSSV: 20235342
# **Ngày:** 2025-10-28
#
# ## Tóm tắt
# Mẫu báo cáo cơ bản cho Jupyter Notebook.

# %%
import numpy as np, matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
y = 2.5*x + np.random.randn(100)*5
plt.scatter(x, y)
plt.title("Ví dụ dữ liệu minh hoạ")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Kết luận
# Đây là ví dụ đầu tiên về notebook báo cáo.
