# %% [markdown]
# # Báo cáo mô hình hồi quy tuyến tính

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(0)
x = np.linspace(0, 50, 100)
y = 3*x + 10 + np.random.randn(100)*5
b1, b0 = np.polyfit(x, y, 1)
plt.scatter(x, y, label="data")
plt.plot(x, b1*x + b0, color="red", label="fit")
plt.legend(); plt.show()
b0, b1
# Out:
# (11.04235723921102, 2.970267313538455)
